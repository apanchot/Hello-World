# %% [markdown]
# <a href="https://colab.research.google.com/github/apanchot/Hello-World/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
database=pd.read_csv("https://raw.githubusercontent.com/apanchot/data_mining/master/A2Z_Insurance.csv")
database.insert(2,"Policy Age",2019 - database['First Policy´s Year'].values)
database.insert(4,"Person Age",2019 - database['Brithday Year'].values)
database.insert(7,"Gross Yearly Salary", 12*database['Gross Monthly Salary'].values)
database.insert(12,"Total Amount Paid Out Per Year",database['Claims Rate'].values*(database['Premiums in LOB: Motor'].values+database['Premiums in LOB: Household'].values+database['Premiums in LOB: Health'].values+database['Premiums in LOB: Work Compensations'].values+database['Premiums in LOB:  Life'].values)/2 )

# %%
database.head()
# Out:
#    Customer Identity  ...  Premiums in LOB: Work Compensations
# 0                  1  ...                                16.89
# 1                  2  ...                               106.13
# 2                  3  ...                                99.02
# 3                  4  ...                                28.34
# 4                  5  ...                                41.45
#
# [5 rows x 18 columns]

# %%
database.corr()
# Out:
#                                      Customer Identity  ...  Premiums in LOB: Work Compensations
# Customer Identity                             1.000000  ...                             0.017045
# First Policy´s Year                           0.013598  ...                            -0.004296
# Policy Age                                   -0.013598  ...                             0.004296
# Brithday Year                                 0.008823  ...                             0.208049
# Person Age                                   -0.008823  ...                            -0.208049
# Gross Monthly Salary                         -0.009427  ...                            -0.174798
# Gross Yearly Salary                          -0.009427  ...                            -0.174798
# Geographic Living Area                       -0.005468  ...                             0.003561
# Has Children (Y=1)                           -0.002063  ...                            -0.085566
# ...

# %%
plt.matshow(database.corr())
plt.show()

# %%
print(database['Person Age'].mean())
print(database['Person Age'].median())
# Out:
# 50.99221714174531
# 51.0

# %%
data_age_over_avg =
